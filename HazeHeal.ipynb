# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
from PIL import Image
import time
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
import tensorflow as tf
from tensorflow.keras import layers

def mish(x):
    return x * tf.tanh(tf.nn.softplus(x))

# %%
class InstanceNormalization(layers.Layer):

    def __init__(self, epsilon=1e-5):
        super(InstanceNormalization, self).__init__()
        self.epsilon = epsilon

    def build(self, input_shape):
        depth = input_shape[-1]
        self.scale = self.add_weight(
            shape=[depth],
            initializer='ones',
            trainable=True,
            name='scale'
        )
        self.offset = self.add_weight(
            shape=[depth],
            initializer='zeros',
            trainable=True,
            name='offset'
        )

    def call(self, x):
        # Calculate mean
        mean = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
        
        # Calculate variance: E[(x - E[x])²]
        variance = tf.reduce_mean(
            tf.square(x - mean), 
            axis=[1, 2], 
            keepdims=True
        )
        
        # Normalize
        inv = tf.sqrt(variance + self.epsilon)
        normalized = (x - mean) / inv
        
        return self.scale[None, None, None, :] * normalized + self.offset[None, None, None, :]

    def compute_output_shape(self, input_shape):
        return input_shape

# %%
class SpectralNormalization(layers.Layer):
    def __init__(self, layer, **kwargs):
        super(SpectralNormalization, self).__init__(**kwargs)
        self.layer = layer

    def build(self, input_shape):
        self.layer.build(input_shape)
        self.u = self.add_weight(
            shape=(1, self.layer.kernel.shape[-1]),
            initializer="random_normal",
            trainable=False,
            name="spectral_u"
        )
        super(SpectralNormalization, self).build(input_shape)

    def call(self, inputs, training=None):
        w = self.layer.kernel
        w_shape = w.shape
        w = tf.reshape(w, [-1, w_shape[-1]])
        v = tf.linalg.matvec(tf.transpose(w), self.u, transpose_a=True)
        v = tf.linalg.normalize(v)[0]
        u = tf.linalg.matvec(w, v)
        u = tf.linalg.normalize(u)[0]
        self.u.assign(u)
        sigma = tf.reduce_sum(tf.matmul(tf.matmul(tf.transpose(u), w), v))
        self.layer.kernel.assign(self.layer.kernel / sigma)
        return self.layer(inputs, training=training)

    def compute_output_shape(self, input_shape):
        return self.layer.compute_output_shape(input_shape)

# %%
class DehazeGAN:
    def __init__(self, image_size=(256, 256)):
        self.image_size = image_size
        self.generator = self._build_generator()
        self.discriminator = self._build_discriminator()

        lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=1e-4,
            decay_steps=100000,
            decay_rate=0.96,
            staircase=True
        )

        # Initialize optimizers
        self.generator_optimizer = keras.optimizers.Adam(learning_rate=lr_schedule, beta_1=0.5)
        self.discriminator_optimizer = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=True)

        # Initialize loss functions
        self.gan_loss = keras.losses.BinaryCrossentropy(from_logits=True)
        self.pixel_loss = keras.losses.MeanAbsoluteError()

        # Initialize metrics
        self.gen_loss_tracker = tf.keras.metrics.Mean(name='generator_loss')
        self.disc_loss_tracker = tf.keras.metrics.Mean(name='discriminator_loss')

    def _build_generator(self):
        """Build generator network with instance normalization."""
        def residual_block(x, filters, kernel_size=3):
            shortcut = x
            x = layers.Conv2D(filters, kernel_size, padding='same')(x)
            x = InstanceNormalization()(x)
            x = layers.Activation(mish)(x)
            x = layers.Conv2D(filters, kernel_size, padding='same')(x)
            x = InstanceNormalization()(x)
            x = layers.Add()([shortcut, x])
            return x

        # Input layer
        inputs = layers.Input(shape=(*self.image_size, 3))

        # Initial convolution with instance normalization
        x = layers.Conv2D(64, 7, padding='same')(inputs)
        x = InstanceNormalization()(x)
        x = layers.Activation(mish)(x)

        # Encoder with instance normalization
        x = layers.Conv2D(128, 3, strides=2, padding='same')(x)
        x = InstanceNormalization()(x)
        x = layers.Activation(mish)(x)

        x = layers.Conv2D(256, 3, strides=2, padding='same')(x)
        x = InstanceNormalization()(x)
        x = layers.Activation(mish)(x)

        # Residual blocks
        for _ in range(9):
            x = residual_block(x, 256)

        # Decoder with instance normalization
        x = layers.Conv2DTranspose(128, 3, strides=2, padding='same')(x)
        x = InstanceNormalization()(x)
        x = layers.Activation(mish)(x)

        x = layers.Conv2DTranspose(64, 3, strides=2, padding='same')(x)
        x = InstanceNormalization()(x)
        x = layers.Activation(mish)(x)

        # Output layer
        outputs = layers.Conv2D(3, 7, padding='same', activation='tanh')(x)

        return keras.Model(inputs, outputs, name='generator')

    def _build_discriminator(self):
        """Build discriminator network."""
        def discriminator_block(x, filters, strides=2):
            x = layers.Conv2D(filters, 4, strides=strides, padding='same', 
                            kernel_initializer='orthogonal')(x)
            x = layers.LeakyReLU(0.2)(x)
            return x

        # Input layer
        inputs = layers.Input(shape=(*self.image_size, 3))

        # Discriminator blocks
        x = discriminator_block(inputs, 64)
        x = discriminator_block(x, 128)
        x = discriminator_block(x, 256)
        x = discriminator_block(x, 512, strides=1)

        # Output layer
        outputs = layers.Conv2D(1, 4, strides=1, padding='same')(x)

        return keras.Model(inputs, outputs, name='discriminator')

    @tf.function
    def train_step(self, hazy_images, clean_images):
        """Single training step."""
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            # Generate fake images
            fake_images = self.generator(hazy_images, training=True)

            # Discriminator predictions
            real_output = self.discriminator(clean_images, training=True)
            fake_output = self.discriminator(fake_images, training=True)

            # Calculate losses
            gen_loss = self._generator_loss(fake_output, fake_images, clean_images)
            disc_loss = self._discriminator_loss(real_output, fake_output)

        # Calculate gradients
        gen_gradients = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        disc_gradients = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        # Apply gradients
        self.generator_optimizer.apply_gradients(
            zip(gen_gradients, self.generator.trainable_variables)
        )
        self.discriminator_optimizer.apply_gradients(
            zip(disc_gradients, self.discriminator.trainable_variables)
        )

        # Update metrics
        self.gen_loss_tracker.update_state(gen_loss)
        self.disc_loss_tracker.update_state(disc_loss)

        return {
            'gen_loss': gen_loss,
            'disc_loss': disc_loss
        }

    def _generator_loss(self, fake_output, fake_images, clean_images):
        """Calculate generator loss."""
        gan_loss = self.gan_loss(tf.ones_like(fake_output), fake_output)
        l1_loss = self.pixel_loss(clean_images, fake_images) * 100  # Pixel loss weight
        return gan_loss + l1_loss

    def _discriminator_loss(self, real_output, fake_output):
        """Calculate discriminator loss."""
        real_loss = self.gan_loss(tf.ones_like(real_output) * 0.9, real_output)
        fake_loss = self.gan_loss(tf.zeros_like(fake_output) + 0.1, fake_output)
        return (real_loss + fake_loss) * 0.5

# %%
class DehazeDataProcessor:
    def __init__(self, hazy_dir, gt_dir, image_size=(256, 256), batch_size=4):
        self.hazy_dir = hazy_dir
        self.gt_dir = gt_dir
        self.image_size = image_size
        self.batch_size = batch_size
    
    def load_and_preprocess_image(self, image_path):
        """Load and preprocess a single image with augmentation."""
        img = tf.io.read_file(image_path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, self.image_size)
        img = tf.cast(img, tf.float32) / 127.5 - 1  # Normalize to [-1, 1]
        return img

    
    def create_dataset(self):
        """Create TensorFlow dataset pipeline."""  
        # Get file paths
        hazy_paths = sorted(glob.glob(os.path.join(self.hazy_dir, '*.*')))
        gt_paths = sorted(glob.glob(os.path.join(self.gt_dir, '*.*')))
        
        logger.info(f"Found {len(hazy_paths)} hazy images and {len(gt_paths)} ground truth images")
        assert len(hazy_paths) == len(gt_paths), "Number of hazy and ground truth images must match"
        
        # Create dataset
        dataset = tf.data.Dataset.from_tensor_slices((hazy_paths, gt_paths))
        dataset = dataset.map(
            lambda x, y: (
                self.load_and_preprocess_image(x),
                self.load_and_preprocess_image(y)
            ),
            num_parallel_calls=tf.data.AUTOTUNE
        )
        
        # Configure dataset
        dataset = dataset.shuffle(len(hazy_paths))
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset, len(hazy_paths)

# %%
class DehazeTrainer:
    def __init__(self, model, dataset, num_epochs, checkpoint_dir='./checkpoints'):
        self.model = model
        self.dataset = dataset
        self.num_epochs = num_epochs
        self.checkpoint_dir = checkpoint_dir
        
        # Create directories
        os.makedirs(checkpoint_dir, exist_ok=True)
        os.makedirs('samples', exist_ok=True)
        
        # Setup checkpointing
        self.checkpoint = tf.train.Checkpoint(
            generator=model.generator,
            discriminator=model.discriminator,
            generator_optimizer=model.generator_optimizer,
            discriminator_optimizer=model.discriminator_optimizer
        )
        self.checkpoint_manager = tf.train.CheckpointManager(
            self.checkpoint, checkpoint_dir, max_to_keep=3
        )
    
    def train(self):
        """Training loop."""
        start_time = time.time()
        
        for epoch in range(self.num_epochs):
            print(f"\nStarting epoch {epoch + 1}/{self.num_epochs}", flush=True)
            time.sleep(0.1)
            
            # Reset metrics
            self.model.gen_loss_tracker.reset_state()
            self.model.disc_loss_tracker.reset_state()
            
            # Train on batches
            for batch_idx, (hazy_batch, clean_batch) in enumerate(self.dataset):
                losses = self.model.train_step(hazy_batch, clean_batch)
                
                if batch_idx % 10 == 0:
                    print(
                        f"Batch {batch_idx}: "
                        f"Generator Loss = {losses['gen_loss']:.4f}, "
                        f"Discriminator Loss = {losses['disc_loss']:.4f}",
                        flush=True
                    )
            
            # Save checkpoint and generate samples
            if (epoch + 1) % 10 == 0:
                self.checkpoint_manager.save()
                self._generate_and_save_samples(epoch + 1)
            
            # Log epoch results
            print(
                f"Epoch {epoch + 1}: "
                f"Generator Loss = {self.model.gen_loss_tracker.result():.4f}, "
                f"Discriminator Loss = {self.model.disc_loss_tracker.result():.4f}",
                flush=True
            )
        
        total_time = time.time() - start_time
        print(f"\nTraining completed in {total_time / 60:.2f} minutes", flush = True)


    def _generate_and_save_samples(self, epoch):
        """Generate and save sample images."""
        # Get a batch of test images
        test_batch = next(iter(self.dataset))
        hazy_images, clean_images = test_batch
        
        # Generate dehazed images
        generated_images = self.model.generator(hazy_images, training=False)
        
        # Create figure
        plt.figure(figsize=(15, 5))
        
        # Plot images
        for i in range(min(3, len(hazy_images))):
            # Hazy image
            plt.subplot(3, 3, i*3 + 1)
            plt.imshow(hazy_images[i] * 0.5 + 0.5)
            plt.axis('off')
            plt.title('Hazy')
            
            # Generated image
            plt.subplot(3, 3, i*3 + 2)
            plt.imshow(generated_images[i] * 0.5 + 0.5)
            plt.axis('off')
            plt.title('Generated')
            
            # Ground truth
            plt.subplot(3, 3, i*3 + 3)
            plt.imshow(clean_images[i] * 0.5 + 0.5)
            plt.axis('off')
            plt.title('Ground Truth')
        
        plt.savefig(f'samples/epoch_{epoch}.png')
        plt.close()

# %%
def main():
    # Configuration
    HAZY_DIR = '/kaggle/input/hazing-images-dataset-cvpr-2019/hazy'
    GT_DIR = '/kaggle/input/hazing-images-dataset-cvpr-2019/GT'
    IMAGE_SIZE = (256, 256)
    BATCH_SIZE = 4
    NUM_EPOCHS = 5000
    CHECKPOINT_DIR = './checkpoints'

    # Set up data processor
    data_processor = DehazeDataProcessor(
        HAZY_DIR,
        GT_DIR,
        image_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE
    )
    
    # Create dataset
    dataset, num_images = data_processor.create_dataset()
    logger.info(f"Dataset created with {num_images} images")
    
    # Initialize model
    model = DehazeGAN(image_size=IMAGE_SIZE)
    logger.info("Model initialized")
    
    # Create trainer and start training
    trainer = DehazeTrainer(model, dataset, NUM_EPOCHS, checkpoint_dir=CHECKPOINT_DIR)
    logger.info("Starting training...")
    trainer.train()
    
    # Load and test the saved model
    # test_image_path = '/kaggle/input/hazing-images-dataset-cvpr-2019/hazy/01_hazy.png'
    # logger.info("Testing saved model...")
    # test_saved_model(model, test_image_path)

# %%
import tensorflow as tf
tf.get_logger().setLevel('DEBUG')

if __name__ == "__main__":
    main()
# Out:
# Starting epoch 1/5000
# Batch 0: Generator Loss = 61.8142, Discriminator Loss = 0.6830
# Batch 10: Generator Loss = 32.5270, Discriminator Loss = 0.6993
# Epoch 1: Generator Loss = 42.8812, Discriminator Loss = 0.6957
#
# Starting epoch 2/5000
# Batch 0: Generator Loss = 29.9445, Discriminator Loss = 0.6911
# Batch 10: Generator Loss = 32.0863, Discriminator Loss = 0.7064
# Epoch 2: Generator Loss = 34.1445, Discriminator Loss = 0.6973
#
# Starting epoch 3/5000
# Batch 0: Generator Loss = 34.2007, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 32.9209, Discriminator Loss = 0.6952
# Epoch 3: Generator Loss = 32.7646, Discriminator Loss = 0.6967
#
# Starting epoch 4/5000
# Batch 0: Generator Loss = 28.1053, Discriminator Loss = 0.6973
# Batch 10: Generator Loss = 29.8769, Discriminator Loss = 0.6872
# Epoch 4: Generator Loss = 31.7570, Discriminator Loss = 0.6952
#
# Starting epoch 5/5000
# Batch 0: Generator Loss = 29.6275, Discriminator Loss = 0.6981
# Batch 10: Generator Loss = 28.7607, Discriminator Loss = 0.6916
# Epoch 5: Generator Loss = 30.5706, Discriminator Loss = 0.6943
#
# Starting epoch 6/5000
# Batch 0: Generator Loss = 33.5843, Discriminator Loss = 0.6951
# Batch 10: Generator Loss = 34.1688, Discriminator Loss = 0.6881
# Epoch 6: Generator Loss = 30.5458, Discriminator Loss = 0.6930
#
# Starting epoch 7/5000
# Batch 0: Generator Loss = 27.7768, Discriminator Loss = 0.6916
# Batch 10: Generator Loss = 27.0089, Discriminator Loss = 0.6935
# Epoch 7: Generator Loss = 30.1633, Discriminator Loss = 0.6923
#
# Starting epoch 8/5000
# Batch 0: Generator Loss = 32.8774, Discriminator Loss = 0.6890
# Batch 10: Generator Loss = 27.5854, Discriminator Loss = 0.6916
# Epoch 8: Generator Loss = 29.5868, Discriminator Loss = 0.6914
#
# Starting epoch 9/5000
# Batch 0: Generator Loss = 24.0207, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 30.1094, Discriminator Loss = 0.6925
# Epoch 9: Generator Loss = 29.1295, Discriminator Loss = 0.6898
#
# Starting epoch 10/5000
# Batch 0: Generator Loss = 27.2764, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 29.7206, Discriminator Loss = 0.6918
# Epoch 10: Generator Loss = 29.2012, Discriminator Loss = 0.6908
#
# Starting epoch 11/5000
# Batch 0: Generator Loss = 29.7657, Discriminator Loss = 0.6860
# Batch 10: Generator Loss = 26.4012, Discriminator Loss = 0.6945
# Epoch 11: Generator Loss = 28.5695, Discriminator Loss = 0.6890
#
# Starting epoch 12/5000
# Batch 0: Generator Loss = 25.2375, Discriminator Loss = 0.6894
# Batch 10: Generator Loss = 26.0376, Discriminator Loss = 0.6926
# Epoch 12: Generator Loss = 28.5477, Discriminator Loss = 0.6888
#
# Starting epoch 13/5000
# Batch 0: Generator Loss = 26.5055, Discriminator Loss = 0.6857
# Batch 10: Generator Loss = 29.8295, Discriminator Loss = 0.6870
# Epoch 13: Generator Loss = 28.2743, Discriminator Loss = 0.6877
#
# Starting epoch 14/5000
# Batch 0: Generator Loss = 27.9367, Discriminator Loss = 0.6842
# Batch 10: Generator Loss = 27.1127, Discriminator Loss = 0.6882
# Epoch 14: Generator Loss = 28.1533, Discriminator Loss = 0.6872
#
# Starting epoch 15/5000
# Batch 0: Generator Loss = 23.9911, Discriminator Loss = 0.6991
# Batch 10: Generator Loss = 26.3882, Discriminator Loss = 0.6977
# Epoch 15: Generator Loss = 27.4307, Discriminator Loss = 0.6877
#
# Starting epoch 16/5000
# Batch 0: Generator Loss = 33.0225, Discriminator Loss = 0.6828
# Batch 10: Generator Loss = 25.8552, Discriminator Loss = 0.6935
# Epoch 16: Generator Loss = 27.7258, Discriminator Loss = 0.6871
#
# Starting epoch 17/5000
# Batch 0: Generator Loss = 23.0285, Discriminator Loss = 0.6907
# Batch 10: Generator Loss = 26.0699, Discriminator Loss = 0.6832
# Epoch 17: Generator Loss = 27.1650, Discriminator Loss = 0.6869
#
# Starting epoch 18/5000
# Batch 0: Generator Loss = 28.8043, Discriminator Loss = 0.6799
# Batch 10: Generator Loss = 33.6358, Discriminator Loss = 0.6757
# Epoch 18: Generator Loss = 27.3986, Discriminator Loss = 0.6867
#
# Starting epoch 19/5000
# Batch 0: Generator Loss = 23.0357, Discriminator Loss = 0.6887
# Batch 10: Generator Loss = 31.6257, Discriminator Loss = 0.6767
# Epoch 19: Generator Loss = 26.4587, Discriminator Loss = 0.6851
#
# Starting epoch 20/5000
# Batch 0: Generator Loss = 25.4896, Discriminator Loss = 0.6817
# Batch 10: Generator Loss = 21.5005, Discriminator Loss = 0.6898
# Epoch 20: Generator Loss = 26.3452, Discriminator Loss = 0.6877
#
# Starting epoch 21/5000
# Batch 0: Generator Loss = 26.5166, Discriminator Loss = 0.6809
# Batch 10: Generator Loss = 26.9663, Discriminator Loss = 0.6820
# Epoch 21: Generator Loss = 26.6675, Discriminator Loss = 0.6851
#
# Starting epoch 22/5000
# Batch 0: Generator Loss = 24.7814, Discriminator Loss = 0.6942
# Batch 10: Generator Loss = 25.6634, Discriminator Loss = 0.6916
# Epoch 22: Generator Loss = 26.3314, Discriminator Loss = 0.6846
#
# Starting epoch 23/5000
# Batch 0: Generator Loss = 28.3240, Discriminator Loss = 0.7003
# Batch 10: Generator Loss = 25.9498, Discriminator Loss = 0.6789
# Epoch 23: Generator Loss = 26.8371, Discriminator Loss = 0.6881
#
# Starting epoch 24/5000
# Batch 0: Generator Loss = 24.0992, Discriminator Loss = 0.6907
# Batch 10: Generator Loss = 26.5463, Discriminator Loss = 0.6804
# Epoch 24: Generator Loss = 25.7149, Discriminator Loss = 0.6847
#
# Starting epoch 25/5000
# Batch 0: Generator Loss = 31.6647, Discriminator Loss = 0.6679
# Batch 10: Generator Loss = 28.1896, Discriminator Loss = 0.6735
# Epoch 25: Generator Loss = 25.4751, Discriminator Loss = 0.6859
#
# Starting epoch 26/5000
# Batch 0: Generator Loss = 25.3908, Discriminator Loss = 0.6808
# Batch 10: Generator Loss = 27.1871, Discriminator Loss = 0.6888
# Epoch 26: Generator Loss = 25.2847, Discriminator Loss = 0.6841
#
# Starting epoch 27/5000
# Batch 0: Generator Loss = 23.1837, Discriminator Loss = 0.6967
# Batch 10: Generator Loss = 27.9342, Discriminator Loss = 0.6917
# Epoch 27: Generator Loss = 25.6163, Discriminator Loss = 0.6846
#
# Starting epoch 28/5000
# Batch 0: Generator Loss = 30.9892, Discriminator Loss = 0.6813
# Batch 10: Generator Loss = 26.4873, Discriminator Loss = 0.6699
# Epoch 28: Generator Loss = 25.4623, Discriminator Loss = 0.6858
#
# Starting epoch 29/5000
# Batch 0: Generator Loss = 25.9218, Discriminator Loss = 0.6844
# Batch 10: Generator Loss = 22.8255, Discriminator Loss = 0.6921
# Epoch 29: Generator Loss = 24.9335, Discriminator Loss = 0.6849
#
# Starting epoch 30/5000
# Batch 0: Generator Loss = 24.1302, Discriminator Loss = 0.6725
# Batch 10: Generator Loss = 25.8715, Discriminator Loss = 0.6892
# Epoch 30: Generator Loss = 25.0395, Discriminator Loss = 0.6847
#
# Starting epoch 31/5000
# Batch 0: Generator Loss = 21.7549, Discriminator Loss = 0.6900
# Batch 10: Generator Loss = 25.1759, Discriminator Loss = 0.6752
# Epoch 31: Generator Loss = 24.8411, Discriminator Loss = 0.6843
#
# Starting epoch 32/5000
# Batch 0: Generator Loss = 24.3586, Discriminator Loss = 0.6912
# Batch 10: Generator Loss = 26.1309, Discriminator Loss = 0.6848
# Epoch 32: Generator Loss = 23.9168, Discriminator Loss = 0.6859
#
# Starting epoch 33/5000
# Batch 0: Generator Loss = 25.7293, Discriminator Loss = 0.6746
# Batch 10: Generator Loss = 23.0810, Discriminator Loss = 0.6820
# Epoch 33: Generator Loss = 24.4136, Discriminator Loss = 0.6857
#
# Starting epoch 34/5000
# Batch 0: Generator Loss = 22.4198, Discriminator Loss = 0.6874
# Batch 10: Generator Loss = 25.5214, Discriminator Loss = 0.6923
# Epoch 34: Generator Loss = 24.0228, Discriminator Loss = 0.6853
#
# Starting epoch 35/5000
# Batch 0: Generator Loss = 21.5215, Discriminator Loss = 0.6841
# Batch 10: Generator Loss = 22.4633, Discriminator Loss = 0.6890
# Epoch 35: Generator Loss = 23.9076, Discriminator Loss = 0.6861
#
# Starting epoch 36/5000
# Batch 0: Generator Loss = 25.5754, Discriminator Loss = 0.6764
# Batch 10: Generator Loss = 23.3456, Discriminator Loss = 0.6928
# Epoch 36: Generator Loss = 23.3046, Discriminator Loss = 0.6860
#
# Starting epoch 37/5000
# Batch 0: Generator Loss = 19.6011, Discriminator Loss = 0.6787
# Batch 10: Generator Loss = 25.1728, Discriminator Loss = 0.7060
# Epoch 37: Generator Loss = 23.2985, Discriminator Loss = 0.6848
#
# Starting epoch 38/5000
# Batch 0: Generator Loss = 25.7747, Discriminator Loss = 0.6840
# Batch 10: Generator Loss = 18.3297, Discriminator Loss = 0.6888
# Epoch 38: Generator Loss = 22.9866, Discriminator Loss = 0.6861
#
# Starting epoch 39/5000
# Batch 0: Generator Loss = 24.7692, Discriminator Loss = 0.6825
# Batch 10: Generator Loss = 19.9922, Discriminator Loss = 0.6924
# Epoch 39: Generator Loss = 22.3146, Discriminator Loss = 0.6869
#
# Starting epoch 40/5000
# Batch 0: Generator Loss = 20.2869, Discriminator Loss = 0.6906
# Batch 10: Generator Loss = 18.3313, Discriminator Loss = 0.6910
# Epoch 40: Generator Loss = 22.3758, Discriminator Loss = 0.6862
#
# Starting epoch 41/5000
# Batch 0: Generator Loss = 20.6654, Discriminator Loss = 0.6969
# Batch 10: Generator Loss = 22.7086, Discriminator Loss = 0.6940
# Epoch 41: Generator Loss = 22.1631, Discriminator Loss = 0.6860
#
# Starting epoch 42/5000
# Batch 0: Generator Loss = 21.8163, Discriminator Loss = 0.6863
# Batch 10: Generator Loss = 25.0007, Discriminator Loss = 0.6862
# Epoch 42: Generator Loss = 22.3362, Discriminator Loss = 0.6875
#
# Starting epoch 43/5000
# Batch 0: Generator Loss = 22.1928, Discriminator Loss = 0.6772
# Batch 10: Generator Loss = 25.5326, Discriminator Loss = 0.6788
# Epoch 43: Generator Loss = 22.5434, Discriminator Loss = 0.6850
#
# Starting epoch 44/5000
# Batch 0: Generator Loss = 25.3750, Discriminator Loss = 0.6952
# Batch 10: Generator Loss = 20.8120, Discriminator Loss = 0.6949
# Epoch 44: Generator Loss = 22.7719, Discriminator Loss = 0.6854
#
# Starting epoch 45/5000
# Batch 0: Generator Loss = 23.1265, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 25.0779, Discriminator Loss = 0.6882
# Epoch 45: Generator Loss = 22.6596, Discriminator Loss = 0.6852
#
# Starting epoch 46/5000
# Batch 0: Generator Loss = 19.3865, Discriminator Loss = 0.6949
# Batch 10: Generator Loss = 24.3417, Discriminator Loss = 0.6815
# Epoch 46: Generator Loss = 21.2675, Discriminator Loss = 0.6877
#
# Starting epoch 47/5000
# Batch 0: Generator Loss = 20.5260, Discriminator Loss = 0.6958
# Batch 10: Generator Loss = 17.2797, Discriminator Loss = 0.6850
# Epoch 47: Generator Loss = 21.3778, Discriminator Loss = 0.6858
#
# Starting epoch 48/5000
# Batch 0: Generator Loss = 19.8014, Discriminator Loss = 0.6990
# Batch 10: Generator Loss = 19.9551, Discriminator Loss = 0.6913
# Epoch 48: Generator Loss = 21.8386, Discriminator Loss = 0.6868
#
# Starting epoch 49/5000
# Batch 0: Generator Loss = 23.7598, Discriminator Loss = 0.6797
# Batch 10: Generator Loss = 21.7800, Discriminator Loss = 0.6931
# Epoch 49: Generator Loss = 20.6107, Discriminator Loss = 0.6863
#
# Starting epoch 50/5000
# Batch 0: Generator Loss = 19.7290, Discriminator Loss = 0.6783
# Batch 10: Generator Loss = 23.3847, Discriminator Loss = 0.6802
# Epoch 50: Generator Loss = 20.5441, Discriminator Loss = 0.6865
#
# Starting epoch 51/5000
# Batch 0: Generator Loss = 22.6138, Discriminator Loss = 0.6799
# Batch 10: Generator Loss = 18.5813, Discriminator Loss = 0.6904
# Epoch 51: Generator Loss = 20.7226, Discriminator Loss = 0.6865
#
# Starting epoch 52/5000
# Batch 0: Generator Loss = 19.6313, Discriminator Loss = 0.6849
# Batch 10: Generator Loss = 20.1927, Discriminator Loss = 0.6875
# Epoch 52: Generator Loss = 20.3621, Discriminator Loss = 0.6859
#
# Starting epoch 53/5000
# Batch 0: Generator Loss = 22.8847, Discriminator Loss = 0.6919
# Batch 10: Generator Loss = 21.0082, Discriminator Loss = 0.6771
# Epoch 53: Generator Loss = 20.1874, Discriminator Loss = 0.6877
#
# Starting epoch 54/5000
# Batch 0: Generator Loss = 19.5718, Discriminator Loss = 0.6878
# Batch 10: Generator Loss = 22.0228, Discriminator Loss = 0.6899
# Epoch 54: Generator Loss = 20.5350, Discriminator Loss = 0.6860
#
# Starting epoch 55/5000
# Batch 0: Generator Loss = 24.1254, Discriminator Loss = 0.6765
# Batch 10: Generator Loss = 21.9867, Discriminator Loss = 0.6797
# Epoch 55: Generator Loss = 19.4724, Discriminator Loss = 0.6864
#
# Starting epoch 56/5000
# Batch 0: Generator Loss = 21.9105, Discriminator Loss = 0.6736
# Batch 10: Generator Loss = 19.7052, Discriminator Loss = 0.6948
# Epoch 56: Generator Loss = 19.9911, Discriminator Loss = 0.6858
#
# Starting epoch 57/5000
# Batch 0: Generator Loss = 17.1320, Discriminator Loss = 0.6950
# Batch 10: Generator Loss = 20.4082, Discriminator Loss = 0.6894
# Epoch 57: Generator Loss = 20.1374, Discriminator Loss = 0.6855
#
# Starting epoch 58/5000
# Batch 0: Generator Loss = 24.2665, Discriminator Loss = 0.6940
# Batch 10: Generator Loss = 17.1709, Discriminator Loss = 0.6848
# Epoch 58: Generator Loss = 19.8384, Discriminator Loss = 0.6873
#
# Starting epoch 59/5000
# Batch 0: Generator Loss = 19.9282, Discriminator Loss = 0.6742
# Batch 10: Generator Loss = 16.6849, Discriminator Loss = 0.6855
# Epoch 59: Generator Loss = 19.7496, Discriminator Loss = 0.6853
#
# Starting epoch 60/5000
# Batch 0: Generator Loss = 18.0011, Discriminator Loss = 0.6927
# Batch 10: Generator Loss = 20.7371, Discriminator Loss = 0.6933
# Epoch 60: Generator Loss = 20.2774, Discriminator Loss = 0.6853
#
# Starting epoch 61/5000
# Batch 0: Generator Loss = 19.6985, Discriminator Loss = 0.6838
# Batch 10: Generator Loss = 18.1281, Discriminator Loss = 0.6948
# Epoch 61: Generator Loss = 18.8470, Discriminator Loss = 0.6859
#
# Starting epoch 62/5000
# Batch 0: Generator Loss = 16.2818, Discriminator Loss = 0.6884
# Batch 10: Generator Loss = 20.3720, Discriminator Loss = 0.6871
# Epoch 62: Generator Loss = 18.4430, Discriminator Loss = 0.6857
#
# Starting epoch 63/5000
# Batch 0: Generator Loss = 17.9028, Discriminator Loss = 0.6891
# Batch 10: Generator Loss = 19.4550, Discriminator Loss = 0.6826
# Epoch 63: Generator Loss = 18.9424, Discriminator Loss = 0.6853
#
# Starting epoch 64/5000
# Batch 0: Generator Loss = 19.4831, Discriminator Loss = 0.6920
# Batch 10: Generator Loss = 20.5660, Discriminator Loss = 0.6862
# Epoch 64: Generator Loss = 18.9383, Discriminator Loss = 0.6855
#
# Starting epoch 65/5000
# Batch 0: Generator Loss = 18.3285, Discriminator Loss = 0.6852
# Batch 10: Generator Loss = 14.8437, Discriminator Loss = 0.6925
# Epoch 65: Generator Loss = 18.3060, Discriminator Loss = 0.6858
#
# Starting epoch 66/5000
# Batch 0: Generator Loss = 17.4170, Discriminator Loss = 0.6907
# Batch 10: Generator Loss = 17.2641, Discriminator Loss = 0.6807
# Epoch 66: Generator Loss = 18.0314, Discriminator Loss = 0.6851
#
# Starting epoch 67/5000
# Batch 0: Generator Loss = 28.1901, Discriminator Loss = 0.6921
# Batch 10: Generator Loss = 17.0948, Discriminator Loss = 0.6872
# Epoch 67: Generator Loss = 18.9836, Discriminator Loss = 0.6849
#
# Starting epoch 68/5000
# Batch 0: Generator Loss = 28.8260, Discriminator Loss = 0.6903
# Batch 10: Generator Loss = 18.8162, Discriminator Loss = 0.6868
# Epoch 68: Generator Loss = 18.6752, Discriminator Loss = 0.6857
#
# Starting epoch 69/5000
# Batch 0: Generator Loss = 19.2125, Discriminator Loss = 0.6851
# Batch 10: Generator Loss = 14.3607, Discriminator Loss = 0.6884
# Epoch 69: Generator Loss = 17.6328, Discriminator Loss = 0.6848
#
# Starting epoch 70/5000
# Batch 0: Generator Loss = 18.4675, Discriminator Loss = 0.6927
# Batch 10: Generator Loss = 14.9107, Discriminator Loss = 0.6878
# Epoch 70: Generator Loss = 17.5801, Discriminator Loss = 0.6848
#
# Starting epoch 71/5000
# Batch 0: Generator Loss = 15.0843, Discriminator Loss = 0.6863
# Batch 10: Generator Loss = 17.6552, Discriminator Loss = 0.6841
# Epoch 71: Generator Loss = 17.6530, Discriminator Loss = 0.6842
#
# Starting epoch 72/5000
# Batch 0: Generator Loss = 18.1023, Discriminator Loss = 0.6855
# Batch 10: Generator Loss = 15.9780, Discriminator Loss = 0.6858
# Epoch 72: Generator Loss = 17.2223, Discriminator Loss = 0.6840
#
# Starting epoch 73/5000
# Batch 0: Generator Loss = 15.9426, Discriminator Loss = 0.6899
# Batch 10: Generator Loss = 19.3899, Discriminator Loss = 0.6789
# Epoch 73: Generator Loss = 17.1997, Discriminator Loss = 0.6855
#
# Starting epoch 74/5000
# Batch 0: Generator Loss = 19.7549, Discriminator Loss = 0.6794
# Batch 10: Generator Loss = 13.3308, Discriminator Loss = 0.6839
# Epoch 74: Generator Loss = 17.3572, Discriminator Loss = 0.6835
#
# Starting epoch 75/5000
# Batch 0: Generator Loss = 14.2540, Discriminator Loss = 0.6861
# Batch 10: Generator Loss = 16.3469, Discriminator Loss = 0.6836
# Epoch 75: Generator Loss = 17.5000, Discriminator Loss = 0.6849
#
# Starting epoch 76/5000
# Batch 0: Generator Loss = 15.0875, Discriminator Loss = 0.6849
# Batch 10: Generator Loss = 19.0154, Discriminator Loss = 0.6793
# Epoch 76: Generator Loss = 16.8751, Discriminator Loss = 0.6834
#
# Starting epoch 77/5000
# Batch 0: Generator Loss = 18.5489, Discriminator Loss = 0.6924
# Batch 10: Generator Loss = 16.6442, Discriminator Loss = 0.6852
# Epoch 77: Generator Loss = 17.2014, Discriminator Loss = 0.6839
#
# Starting epoch 78/5000
# Batch 0: Generator Loss = 18.9200, Discriminator Loss = 0.6773
# Batch 10: Generator Loss = 16.1519, Discriminator Loss = 0.6820
# Epoch 78: Generator Loss = 16.4434, Discriminator Loss = 0.6834
#
# Starting epoch 79/5000
# Batch 0: Generator Loss = 17.5948, Discriminator Loss = 0.6769
# Batch 10: Generator Loss = 14.2335, Discriminator Loss = 0.6892
# Epoch 79: Generator Loss = 16.3619, Discriminator Loss = 0.6845
#
# Starting epoch 80/5000
# Batch 0: Generator Loss = 13.4985, Discriminator Loss = 0.6868
# Batch 10: Generator Loss = 18.8212, Discriminator Loss = 0.6797
# Epoch 80: Generator Loss = 16.4854, Discriminator Loss = 0.6834
#
# Starting epoch 81/5000
# Batch 0: Generator Loss = 15.0412, Discriminator Loss = 0.6814
# Batch 10: Generator Loss = 17.1564, Discriminator Loss = 0.6806
# Epoch 81: Generator Loss = 16.7758, Discriminator Loss = 0.6835
#
# Starting epoch 82/5000
# Batch 0: Generator Loss = 16.6464, Discriminator Loss = 0.6908
# Batch 10: Generator Loss = 16.2327, Discriminator Loss = 0.6815
# Epoch 82: Generator Loss = 18.5895, Discriminator Loss = 0.6832
#
# Starting epoch 83/5000
# Batch 0: Generator Loss = 17.1945, Discriminator Loss = 0.6789
# Batch 10: Generator Loss = 14.0938, Discriminator Loss = 0.6926
# Epoch 83: Generator Loss = 16.5935, Discriminator Loss = 0.6823
#
# Starting epoch 84/5000
# Batch 0: Generator Loss = 14.6268, Discriminator Loss = 0.6899
# Batch 10: Generator Loss = 15.3132, Discriminator Loss = 0.6841
# Epoch 84: Generator Loss = 16.0361, Discriminator Loss = 0.6840
#
# Starting epoch 85/5000
# Batch 0: Generator Loss = 17.3708, Discriminator Loss = 0.6783
# Batch 10: Generator Loss = 15.4543, Discriminator Loss = 0.6791
# Epoch 85: Generator Loss = 15.7927, Discriminator Loss = 0.6825
#
# Starting epoch 86/5000
# Batch 0: Generator Loss = 14.3224, Discriminator Loss = 0.6892
# Batch 10: Generator Loss = 15.4322, Discriminator Loss = 0.6880
# Epoch 86: Generator Loss = 15.6843, Discriminator Loss = 0.6829
#
# Starting epoch 87/5000
# Batch 0: Generator Loss = 17.4163, Discriminator Loss = 0.6736
# Batch 10: Generator Loss = 12.9400, Discriminator Loss = 0.6865
# Epoch 87: Generator Loss = 15.6940, Discriminator Loss = 0.6823
#
# Starting epoch 88/5000
# Batch 0: Generator Loss = 15.6047, Discriminator Loss = 0.6904
# Batch 10: Generator Loss = 15.8708, Discriminator Loss = 0.6831
# Epoch 88: Generator Loss = 17.2876, Discriminator Loss = 0.6825
#
# Starting epoch 89/5000
# Batch 0: Generator Loss = 18.1201, Discriminator Loss = 0.6767
# Batch 10: Generator Loss = 17.1069, Discriminator Loss = 0.6782
# Epoch 89: Generator Loss = 15.7670, Discriminator Loss = 0.6824
#
# Starting epoch 90/5000
# Batch 0: Generator Loss = 17.3303, Discriminator Loss = 0.6799
# Batch 10: Generator Loss = 17.0430, Discriminator Loss = 0.6793
# Epoch 90: Generator Loss = 15.7125, Discriminator Loss = 0.6820
#
# Starting epoch 91/5000
# Batch 0: Generator Loss = 14.3189, Discriminator Loss = 0.6877
# Batch 10: Generator Loss = 18.7556, Discriminator Loss = 0.6699
# Epoch 91: Generator Loss = 15.5105, Discriminator Loss = 0.6824
#
# Starting epoch 92/5000
# Batch 0: Generator Loss = 19.7568, Discriminator Loss = 0.6707
# Batch 10: Generator Loss = 17.1394, Discriminator Loss = 0.6785
# Epoch 92: Generator Loss = 15.4598, Discriminator Loss = 0.6818
#
# Starting epoch 93/5000
# Batch 0: Generator Loss = 15.1460, Discriminator Loss = 0.6765
# Batch 10: Generator Loss = 15.7329, Discriminator Loss = 0.6869
# Epoch 93: Generator Loss = 15.3606, Discriminator Loss = 0.6821
#
# Starting epoch 94/5000
# Batch 0: Generator Loss = 17.1936, Discriminator Loss = 0.6706
# Batch 10: Generator Loss = 15.6510, Discriminator Loss = 0.6770
# Epoch 94: Generator Loss = 15.2677, Discriminator Loss = 0.6814
#
# Starting epoch 95/5000
# Batch 0: Generator Loss = 15.1295, Discriminator Loss = 0.6792
# Batch 10: Generator Loss = 16.7118, Discriminator Loss = 0.6752
# Epoch 95: Generator Loss = 15.3014, Discriminator Loss = 0.6814
#
# Starting epoch 96/5000
# Batch 0: Generator Loss = 16.5468, Discriminator Loss = 0.6811
# Batch 10: Generator Loss = 16.0257, Discriminator Loss = 0.6832
# Epoch 96: Generator Loss = 14.8484, Discriminator Loss = 0.6815
#
# Starting epoch 97/5000
# Batch 0: Generator Loss = 14.4547, Discriminator Loss = 0.6804
# Batch 10: Generator Loss = 14.2373, Discriminator Loss = 0.6828
# Epoch 97: Generator Loss = 14.5116, Discriminator Loss = 0.6817
#
# Starting epoch 98/5000
# Batch 0: Generator Loss = 16.8184, Discriminator Loss = 0.6727
# Batch 10: Generator Loss = 14.3836, Discriminator Loss = 0.6765
# Epoch 98: Generator Loss = 14.5345, Discriminator Loss = 0.6812
#
# Starting epoch 99/5000
# Batch 0: Generator Loss = 12.9375, Discriminator Loss = 0.6863
# Batch 10: Generator Loss = 16.9187, Discriminator Loss = 0.6716
# Epoch 99: Generator Loss = 15.0776, Discriminator Loss = 0.6809
#
# Starting epoch 100/5000
# Batch 0: Generator Loss = 12.7917, Discriminator Loss = 0.6838
# Batch 10: Generator Loss = 15.6337, Discriminator Loss = 0.6810
# Epoch 100: Generator Loss = 14.8397, Discriminator Loss = 0.6810
#
# Starting epoch 101/5000
# Batch 0: Generator Loss = 14.3075, Discriminator Loss = 0.6827
# Batch 10: Generator Loss = 13.5772, Discriminator Loss = 0.6815
# Epoch 101: Generator Loss = 14.8340, Discriminator Loss = 0.6808
#
# Starting epoch 102/5000
# Batch 0: Generator Loss = 15.2879, Discriminator Loss = 0.6832
# Batch 10: Generator Loss = 11.8970, Discriminator Loss = 0.6830
# Epoch 102: Generator Loss = 14.5597, Discriminator Loss = 0.6802
#
# Starting epoch 103/5000
# Batch 0: Generator Loss = 18.1782, Discriminator Loss = 0.6791
# Batch 10: Generator Loss = 16.7767, Discriminator Loss = 0.6766
# Epoch 103: Generator Loss = 15.4040, Discriminator Loss = 0.6809
#
# Starting epoch 104/5000
# Batch 0: Generator Loss = 14.8654, Discriminator Loss = 0.6757
# Batch 10: Generator Loss = 14.8385, Discriminator Loss = 0.6772
# Epoch 104: Generator Loss = 16.1299, Discriminator Loss = 0.6802
#
# Starting epoch 105/5000
# Batch 0: Generator Loss = 15.5549, Discriminator Loss = 0.6791
# Batch 10: Generator Loss = 14.6542, Discriminator Loss = 0.6745
# Epoch 105: Generator Loss = 15.1315, Discriminator Loss = 0.6806
#
# Starting epoch 106/5000
# Batch 0: Generator Loss = 15.0952, Discriminator Loss = 0.6755
# Batch 10: Generator Loss = 13.4921, Discriminator Loss = 0.6812
# Epoch 106: Generator Loss = 14.6788, Discriminator Loss = 0.6807
#
# Starting epoch 107/5000
# Batch 0: Generator Loss = 13.0340, Discriminator Loss = 0.6785
# Batch 10: Generator Loss = 13.3946, Discriminator Loss = 0.6805
# Epoch 107: Generator Loss = 14.3116, Discriminator Loss = 0.6798
#
# Starting epoch 108/5000
# Batch 0: Generator Loss = 17.3608, Discriminator Loss = 0.6750
# Batch 10: Generator Loss = 19.7512, Discriminator Loss = 0.6649
# Epoch 108: Generator Loss = 14.7783, Discriminator Loss = 0.6806
#
# Starting epoch 109/5000
# Batch 0: Generator Loss = 16.4322, Discriminator Loss = 0.6721
# Batch 10: Generator Loss = 14.5893, Discriminator Loss = 0.6802
# Epoch 109: Generator Loss = 14.8027, Discriminator Loss = 0.6801
#
# Starting epoch 110/5000
# Batch 0: Generator Loss = 12.9352, Discriminator Loss = 0.6827
# Batch 10: Generator Loss = 13.7317, Discriminator Loss = 0.6877
# Epoch 110: Generator Loss = 14.3994, Discriminator Loss = 0.6793
#
# Starting epoch 111/5000
# Batch 0: Generator Loss = 12.3408, Discriminator Loss = 0.6853
# Batch 10: Generator Loss = 12.8617, Discriminator Loss = 0.6848
# Epoch 111: Generator Loss = 14.3893, Discriminator Loss = 0.6799
#
# Starting epoch 112/5000
# Batch 0: Generator Loss = 15.9769, Discriminator Loss = 0.6789
# Batch 10: Generator Loss = 12.6477, Discriminator Loss = 0.6796
# Epoch 112: Generator Loss = 14.0304, Discriminator Loss = 0.6792
#
# Starting epoch 113/5000
# Batch 0: Generator Loss = 12.4987, Discriminator Loss = 0.6856
# Batch 10: Generator Loss = 12.1831, Discriminator Loss = 0.6856
# Epoch 113: Generator Loss = 13.9903, Discriminator Loss = 0.6800
#
# Starting epoch 114/5000
# Batch 0: Generator Loss = 15.7180, Discriminator Loss = 0.6767
# Batch 10: Generator Loss = 17.6277, Discriminator Loss = 0.6727
# Epoch 114: Generator Loss = 15.2965, Discriminator Loss = 0.6797
#
# Starting epoch 115/5000
# Batch 0: Generator Loss = 16.4847, Discriminator Loss = 0.6762
# Batch 10: Generator Loss = 13.3189, Discriminator Loss = 0.6857
# Epoch 115: Generator Loss = 14.6843, Discriminator Loss = 0.6798
#
# Starting epoch 116/5000
# Batch 0: Generator Loss = 15.4345, Discriminator Loss = 0.6756
# Batch 10: Generator Loss = 13.4372, Discriminator Loss = 0.6811
# Epoch 116: Generator Loss = 14.3963, Discriminator Loss = 0.6787
#
# Starting epoch 117/5000
# Batch 0: Generator Loss = 13.0495, Discriminator Loss = 0.6874
# Batch 10: Generator Loss = 15.3060, Discriminator Loss = 0.6785
# Epoch 117: Generator Loss = 13.9051, Discriminator Loss = 0.6794
#
# Starting epoch 118/5000
# Batch 0: Generator Loss = 13.4548, Discriminator Loss = 0.6786
# Batch 10: Generator Loss = 13.4889, Discriminator Loss = 0.6737
# Epoch 118: Generator Loss = 14.1140, Discriminator Loss = 0.6786
#
# Starting epoch 119/5000
# Batch 0: Generator Loss = 14.8108, Discriminator Loss = 0.6832
# Batch 10: Generator Loss = 14.1736, Discriminator Loss = 0.6777
# Epoch 119: Generator Loss = 14.0945, Discriminator Loss = 0.6793
#
# Starting epoch 120/5000
# Batch 0: Generator Loss = 12.7426, Discriminator Loss = 0.6806
# Batch 10: Generator Loss = 13.0554, Discriminator Loss = 0.6799
# Epoch 120: Generator Loss = 13.7564, Discriminator Loss = 0.6785
#
# Starting epoch 121/5000
# Batch 0: Generator Loss = 14.8872, Discriminator Loss = 0.6753
# Batch 10: Generator Loss = 12.1973, Discriminator Loss = 0.6798
# Epoch 121: Generator Loss = 13.8289, Discriminator Loss = 0.6791
#
# Starting epoch 122/5000
# Batch 0: Generator Loss = 14.7701, Discriminator Loss = 0.6742
# Batch 10: Generator Loss = 15.6375, Discriminator Loss = 0.6724
# Epoch 122: Generator Loss = 13.6725, Discriminator Loss = 0.6779
#
# Starting epoch 123/5000
# Batch 0: Generator Loss = 13.2750, Discriminator Loss = 0.6827
# Batch 10: Generator Loss = 13.8898, Discriminator Loss = 0.6807
# Epoch 123: Generator Loss = 13.5890, Discriminator Loss = 0.6793
#
# Starting epoch 124/5000
# Batch 0: Generator Loss = 15.6212, Discriminator Loss = 0.6796
# Batch 10: Generator Loss = 12.6511, Discriminator Loss = 0.6820
# Epoch 124: Generator Loss = 13.7342, Discriminator Loss = 0.6785
#
# Starting epoch 125/5000
# Batch 0: Generator Loss = 12.7212, Discriminator Loss = 0.6853
# Batch 10: Generator Loss = 12.8613, Discriminator Loss = 0.6823
# Epoch 125: Generator Loss = 13.5827, Discriminator Loss = 0.6783
#
# Starting epoch 126/5000
# Batch 0: Generator Loss = 14.6566, Discriminator Loss = 0.6834
# Batch 10: Generator Loss = 11.4000, Discriminator Loss = 0.6862
# Epoch 126: Generator Loss = 13.5478, Discriminator Loss = 0.6787
#
# Starting epoch 127/5000
# Batch 0: Generator Loss = 12.8655, Discriminator Loss = 0.6840
# Batch 10: Generator Loss = 13.4340, Discriminator Loss = 0.6810
# Epoch 127: Generator Loss = 13.4866, Discriminator Loss = 0.6778
#
# Starting epoch 128/5000
# Batch 0: Generator Loss = 20.5218, Discriminator Loss = 0.6891
# Batch 10: Generator Loss = 15.8286, Discriminator Loss = 0.6754
# Epoch 128: Generator Loss = 15.5228, Discriminator Loss = 0.6789
#
# Starting epoch 129/5000
# Batch 0: Generator Loss = 23.7668, Discriminator Loss = 0.6665
# Batch 10: Generator Loss = 15.3787, Discriminator Loss = 0.6844
# Epoch 129: Generator Loss = 17.4640, Discriminator Loss = 0.6778
#
# Starting epoch 130/5000
# Batch 0: Generator Loss = 14.8045, Discriminator Loss = 0.6867
# Batch 10: Generator Loss = 13.6927, Discriminator Loss = 0.6828
# Epoch 130: Generator Loss = 14.7419, Discriminator Loss = 0.6788
#
# Starting epoch 131/5000
# Batch 0: Generator Loss = 16.5027, Discriminator Loss = 0.6709
# Batch 10: Generator Loss = 14.2011, Discriminator Loss = 0.6774
# Epoch 131: Generator Loss = 14.1095, Discriminator Loss = 0.6777
#
# Starting epoch 132/5000
# Batch 0: Generator Loss = 14.5377, Discriminator Loss = 0.6785
# Batch 10: Generator Loss = 12.5620, Discriminator Loss = 0.6747
# Epoch 132: Generator Loss = 13.5074, Discriminator Loss = 0.6779
#
# Starting epoch 133/5000
# Batch 0: Generator Loss = 14.3502, Discriminator Loss = 0.6769
# Batch 10: Generator Loss = 11.7673, Discriminator Loss = 0.6803
# Epoch 133: Generator Loss = 13.4537, Discriminator Loss = 0.6776
#
# Starting epoch 134/5000
# Batch 0: Generator Loss = 15.4421, Discriminator Loss = 0.6696
# Batch 10: Generator Loss = 13.7835, Discriminator Loss = 0.6719
# Epoch 134: Generator Loss = 13.3317, Discriminator Loss = 0.6782
#
# Starting epoch 135/5000
# Batch 0: Generator Loss = 12.8183, Discriminator Loss = 0.6785
# Batch 10: Generator Loss = 11.2112, Discriminator Loss = 0.6840
# Epoch 135: Generator Loss = 13.4023, Discriminator Loss = 0.6772
#
# Starting epoch 136/5000
# Batch 0: Generator Loss = 15.2733, Discriminator Loss = 0.6721
# Batch 10: Generator Loss = 12.9219, Discriminator Loss = 0.6774
# Epoch 136: Generator Loss = 12.9748, Discriminator Loss = 0.6776
#
# Starting epoch 137/5000
# Batch 0: Generator Loss = 11.8129, Discriminator Loss = 0.6808
# Batch 10: Generator Loss = 10.8431, Discriminator Loss = 0.6903
# Epoch 137: Generator Loss = 13.1366, Discriminator Loss = 0.6777
#
# Starting epoch 138/5000
# Batch 0: Generator Loss = 12.0579, Discriminator Loss = 0.6809
# Batch 10: Generator Loss = 13.7924, Discriminator Loss = 0.6789
# Epoch 138: Generator Loss = 13.4351, Discriminator Loss = 0.6774
#
# Starting epoch 139/5000
# Batch 0: Generator Loss = 13.4648, Discriminator Loss = 0.6773
# Batch 10: Generator Loss = 14.5037, Discriminator Loss = 0.6739
# Epoch 139: Generator Loss = 13.3702, Discriminator Loss = 0.6774
#
# Starting epoch 140/5000
# Batch 0: Generator Loss = 14.0936, Discriminator Loss = 0.6730
# Batch 10: Generator Loss = 11.8099, Discriminator Loss = 0.6831
# Epoch 140: Generator Loss = 13.3292, Discriminator Loss = 0.6774
#
# Starting epoch 141/5000
# Batch 0: Generator Loss = 13.7172, Discriminator Loss = 0.6780
# Batch 10: Generator Loss = 13.1003, Discriminator Loss = 0.6793
# Epoch 141: Generator Loss = 13.0955, Discriminator Loss = 0.6773
#
# Starting epoch 142/5000
# Batch 0: Generator Loss = 12.9826, Discriminator Loss = 0.6813
# Batch 10: Generator Loss = 12.6473, Discriminator Loss = 0.6833
# Epoch 142: Generator Loss = 12.9494, Discriminator Loss = 0.6769
#
# Starting epoch 143/5000
# Batch 0: Generator Loss = 10.1137, Discriminator Loss = 0.6863
# Batch 10: Generator Loss = 14.9525, Discriminator Loss = 0.6764
# Epoch 143: Generator Loss = 12.9911, Discriminator Loss = 0.6772
#
# Starting epoch 144/5000
# Batch 0: Generator Loss = 11.8822, Discriminator Loss = 0.6855
# Batch 10: Generator Loss = 12.0186, Discriminator Loss = 0.6833
# Epoch 144: Generator Loss = 13.3779, Discriminator Loss = 0.6766
#
# Starting epoch 145/5000
# Batch 0: Generator Loss = 13.7416, Discriminator Loss = 0.6810
# Batch 10: Generator Loss = 14.3141, Discriminator Loss = 0.6712
# Epoch 145: Generator Loss = 13.2717, Discriminator Loss = 0.6770
#
# Starting epoch 146/5000
# Batch 0: Generator Loss = 14.3765, Discriminator Loss = 0.6778
# Batch 10: Generator Loss = 11.9251, Discriminator Loss = 0.6830
# Epoch 146: Generator Loss = 12.9705, Discriminator Loss = 0.6778
#
# Starting epoch 147/5000
# Batch 0: Generator Loss = 13.3829, Discriminator Loss = 0.6693
# Batch 10: Generator Loss = 13.7753, Discriminator Loss = 0.6761
# Epoch 147: Generator Loss = 13.1119, Discriminator Loss = 0.6767
#
# Starting epoch 148/5000
# Batch 0: Generator Loss = 15.5390, Discriminator Loss = 0.6761
# Batch 10: Generator Loss = 10.2429, Discriminator Loss = 0.6854
# Epoch 148: Generator Loss = 13.3210, Discriminator Loss = 0.6771
#
# Starting epoch 149/5000
# Batch 0: Generator Loss = 13.4933, Discriminator Loss = 0.6807
# Batch 10: Generator Loss = 14.1742, Discriminator Loss = 0.6698
# Epoch 149: Generator Loss = 13.2813, Discriminator Loss = 0.6769
#
# Starting epoch 150/5000
# Batch 0: Generator Loss = 13.1573, Discriminator Loss = 0.6785
# Batch 10: Generator Loss = 11.1318, Discriminator Loss = 0.6864
# Epoch 150: Generator Loss = 12.8191, Discriminator Loss = 0.6772
#
# Starting epoch 151/5000
# Batch 0: Generator Loss = 12.9600, Discriminator Loss = 0.6752
# Batch 10: Generator Loss = 13.0996, Discriminator Loss = 0.6788
# Epoch 151: Generator Loss = 12.8416, Discriminator Loss = 0.6766
#
# Starting epoch 152/5000
# Batch 0: Generator Loss = 11.5122, Discriminator Loss = 0.6794
# Batch 10: Generator Loss = 12.9956, Discriminator Loss = 0.6845
# Epoch 152: Generator Loss = 12.7868, Discriminator Loss = 0.6766
#
# Starting epoch 153/5000
# Batch 0: Generator Loss = 13.2817, Discriminator Loss = 0.6805
# Batch 10: Generator Loss = 12.3387, Discriminator Loss = 0.6712
# Epoch 153: Generator Loss = 12.7095, Discriminator Loss = 0.6766
#
# Starting epoch 154/5000
# Batch 0: Generator Loss = 13.0610, Discriminator Loss = 0.6786
# Batch 10: Generator Loss = 11.0735, Discriminator Loss = 0.6805
# Epoch 154: Generator Loss = 12.7808, Discriminator Loss = 0.6760
#
# Starting epoch 155/5000
# Batch 0: Generator Loss = 12.5486, Discriminator Loss = 0.6841
# Batch 10: Generator Loss = 13.4199, Discriminator Loss = 0.6766
# Epoch 155: Generator Loss = 12.9026, Discriminator Loss = 0.6767
#
# Starting epoch 156/5000
# Batch 0: Generator Loss = 12.9861, Discriminator Loss = 0.6737
# Batch 10: Generator Loss = 11.8409, Discriminator Loss = 0.6743
# Epoch 156: Generator Loss = 12.6256, Discriminator Loss = 0.6769
#
# Starting epoch 157/5000
# Batch 0: Generator Loss = 11.3201, Discriminator Loss = 0.6797
# Batch 10: Generator Loss = 12.8170, Discriminator Loss = 0.6754
# Epoch 157: Generator Loss = 12.9184, Discriminator Loss = 0.6769
#
# Starting epoch 158/5000
# Batch 0: Generator Loss = 13.9073, Discriminator Loss = 0.6756
# Batch 10: Generator Loss = 12.6645, Discriminator Loss = 0.6751
# Epoch 158: Generator Loss = 12.6784, Discriminator Loss = 0.6765
#
# Starting epoch 159/5000
# Batch 0: Generator Loss = 12.1972, Discriminator Loss = 0.6697
# Batch 10: Generator Loss = 12.4414, Discriminator Loss = 0.6750
# Epoch 159: Generator Loss = 12.6460, Discriminator Loss = 0.6757
#
# Starting epoch 160/5000
# Batch 0: Generator Loss = 12.4123, Discriminator Loss = 0.6749
# Batch 10: Generator Loss = 12.3191, Discriminator Loss = 0.6726
# Epoch 160: Generator Loss = 12.6181, Discriminator Loss = 0.6763
#
# Starting epoch 161/5000
# Batch 0: Generator Loss = 15.3825, Discriminator Loss = 0.6693
# Batch 10: Generator Loss = 11.9394, Discriminator Loss = 0.6828
# Epoch 161: Generator Loss = 12.6794, Discriminator Loss = 0.6760
#
# Starting epoch 162/5000
# Batch 0: Generator Loss = 13.2737, Discriminator Loss = 0.6800
# Batch 10: Generator Loss = 10.3399, Discriminator Loss = 0.6880
# Epoch 162: Generator Loss = 12.6598, Discriminator Loss = 0.6769
#
# Starting epoch 163/5000
# Batch 0: Generator Loss = 13.7898, Discriminator Loss = 0.6733
# Batch 10: Generator Loss = 12.4938, Discriminator Loss = 0.6770
# Epoch 163: Generator Loss = 12.7625, Discriminator Loss = 0.6762
#
# Starting epoch 164/5000
# Batch 0: Generator Loss = 13.1202, Discriminator Loss = 0.6691
# Batch 10: Generator Loss = 11.1656, Discriminator Loss = 0.6820
# Epoch 164: Generator Loss = 12.7269, Discriminator Loss = 0.6751
#
# Starting epoch 165/5000
# Batch 0: Generator Loss = 10.7675, Discriminator Loss = 0.6789
# Batch 10: Generator Loss = 12.5387, Discriminator Loss = 0.6757
# Epoch 165: Generator Loss = 12.4673, Discriminator Loss = 0.6767
#
# Starting epoch 166/5000
# Batch 0: Generator Loss = 13.4875, Discriminator Loss = 0.6671
# Batch 10: Generator Loss = 11.8356, Discriminator Loss = 0.6828
# Epoch 166: Generator Loss = 12.6749, Discriminator Loss = 0.6757
#
# Starting epoch 167/5000
# Batch 0: Generator Loss = 12.8154, Discriminator Loss = 0.6741
# Batch 10: Generator Loss = 12.4742, Discriminator Loss = 0.6799
# Epoch 167: Generator Loss = 12.5658, Discriminator Loss = 0.6759
#
# Starting epoch 168/5000
# Batch 0: Generator Loss = 15.1710, Discriminator Loss = 0.6676
# Batch 10: Generator Loss = 11.1913, Discriminator Loss = 0.6811
# Epoch 168: Generator Loss = 12.6488, Discriminator Loss = 0.6759
#
# Starting epoch 169/5000
# Batch 0: Generator Loss = 14.6350, Discriminator Loss = 0.6731
# Batch 10: Generator Loss = 11.5378, Discriminator Loss = 0.6885
# Epoch 169: Generator Loss = 12.6078, Discriminator Loss = 0.6764
#
# Starting epoch 170/5000
# Batch 0: Generator Loss = 12.5600, Discriminator Loss = 0.6719
# Batch 10: Generator Loss = 13.5759, Discriminator Loss = 0.6795
# Epoch 170: Generator Loss = 12.7863, Discriminator Loss = 0.6751
#
# Starting epoch 171/5000
# Batch 0: Generator Loss = 12.7739, Discriminator Loss = 0.6760
# Batch 10: Generator Loss = 14.3920, Discriminator Loss = 0.6607
# Epoch 171: Generator Loss = 12.4914, Discriminator Loss = 0.6757
#
# Starting epoch 172/5000
# Batch 0: Generator Loss = 11.7738, Discriminator Loss = 0.6845
# Batch 10: Generator Loss = 12.2054, Discriminator Loss = 0.6796
# Epoch 172: Generator Loss = 12.5102, Discriminator Loss = 0.6764
#
# Starting epoch 173/5000
# Batch 0: Generator Loss = 11.6853, Discriminator Loss = 0.6751
# Batch 10: Generator Loss = 12.0133, Discriminator Loss = 0.6751
# Epoch 173: Generator Loss = 12.5310, Discriminator Loss = 0.6752
#
# Starting epoch 174/5000
# Batch 0: Generator Loss = 12.3204, Discriminator Loss = 0.6769
# Batch 10: Generator Loss = 12.4768, Discriminator Loss = 0.6731
# Epoch 174: Generator Loss = 12.0522, Discriminator Loss = 0.6752
#
# Starting epoch 175/5000
# Batch 0: Generator Loss = 11.9295, Discriminator Loss = 0.6768
# Batch 10: Generator Loss = 12.5981, Discriminator Loss = 0.6772
# Epoch 175: Generator Loss = 12.2647, Discriminator Loss = 0.6755
#
# Starting epoch 176/5000
# Batch 0: Generator Loss = 12.2022, Discriminator Loss = 0.6822
# Batch 10: Generator Loss = 12.4668, Discriminator Loss = 0.6784
# Epoch 176: Generator Loss = 12.1190, Discriminator Loss = 0.6752
#
# Starting epoch 177/5000
# Batch 0: Generator Loss = 12.3172, Discriminator Loss = 0.6812
# Batch 10: Generator Loss = 13.7617, Discriminator Loss = 0.6716
# Epoch 177: Generator Loss = 12.2879, Discriminator Loss = 0.6754
#
# Starting epoch 178/5000
# Batch 0: Generator Loss = 10.5604, Discriminator Loss = 0.6774
# Batch 10: Generator Loss = 11.1528, Discriminator Loss = 0.6870
# Epoch 178: Generator Loss = 12.3379, Discriminator Loss = 0.6752
#
# Starting epoch 179/5000
# Batch 0: Generator Loss = 13.6529, Discriminator Loss = 0.6742
# Batch 10: Generator Loss = 10.2560, Discriminator Loss = 0.6843
# Epoch 179: Generator Loss = 12.2504, Discriminator Loss = 0.6759
#
# Starting epoch 180/5000
# Batch 0: Generator Loss = 12.3080, Discriminator Loss = 0.6697
# Batch 10: Generator Loss = 12.4524, Discriminator Loss = 0.6799
# Epoch 180: Generator Loss = 12.1831, Discriminator Loss = 0.6753
#
# Starting epoch 181/5000
# Batch 0: Generator Loss = 14.1007, Discriminator Loss = 0.6757
# Batch 10: Generator Loss = 14.2502, Discriminator Loss = 0.6680
# Epoch 181: Generator Loss = 12.2959, Discriminator Loss = 0.6749
#
# Starting epoch 182/5000
# Batch 0: Generator Loss = 11.7640, Discriminator Loss = 0.6784
# Batch 10: Generator Loss = 13.1131, Discriminator Loss = 0.6713
# Epoch 182: Generator Loss = 12.2602, Discriminator Loss = 0.6753
#
# Starting epoch 183/5000
# Batch 0: Generator Loss = 12.6165, Discriminator Loss = 0.6818
# Batch 10: Generator Loss = 14.0105, Discriminator Loss = 0.6700
# Epoch 183: Generator Loss = 12.2524, Discriminator Loss = 0.6751
#
# Starting epoch 184/5000
# Batch 0: Generator Loss = 10.3576, Discriminator Loss = 0.6799
# Batch 10: Generator Loss = 10.0840, Discriminator Loss = 0.6777
# Epoch 184: Generator Loss = 12.1302, Discriminator Loss = 0.6755
#
# Starting epoch 185/5000
# Batch 0: Generator Loss = 11.3699, Discriminator Loss = 0.6699
# Batch 10: Generator Loss = 11.5854, Discriminator Loss = 0.6743
# Epoch 185: Generator Loss = 12.0036, Discriminator Loss = 0.6748
#
# Starting epoch 186/5000
# Batch 0: Generator Loss = 13.6537, Discriminator Loss = 0.6653
# Batch 10: Generator Loss = 13.7459, Discriminator Loss = 0.6732
# Epoch 186: Generator Loss = 12.3538, Discriminator Loss = 0.6747
#
# Starting epoch 187/5000
# Batch 0: Generator Loss = 10.6152, Discriminator Loss = 0.6828
# Batch 10: Generator Loss = 10.5347, Discriminator Loss = 0.6854
# Epoch 187: Generator Loss = 12.2028, Discriminator Loss = 0.6752
#
# Starting epoch 188/5000
# Batch 0: Generator Loss = 12.3738, Discriminator Loss = 0.6727
# Batch 10: Generator Loss = 14.6977, Discriminator Loss = 0.6576
# Epoch 188: Generator Loss = 12.2442, Discriminator Loss = 0.6746
#
# Starting epoch 189/5000
# Batch 0: Generator Loss = 13.4273, Discriminator Loss = 0.6716
# Batch 10: Generator Loss = 12.2759, Discriminator Loss = 0.6815
# Epoch 189: Generator Loss = 12.3635, Discriminator Loss = 0.6748
#
# Starting epoch 190/5000
# Batch 0: Generator Loss = 13.3891, Discriminator Loss = 0.6744
# Batch 10: Generator Loss = 12.5023, Discriminator Loss = 0.6713
# Epoch 190: Generator Loss = 12.3469, Discriminator Loss = 0.6754
#
# Starting epoch 191/5000
# Batch 0: Generator Loss = 10.7571, Discriminator Loss = 0.6756
# Batch 10: Generator Loss = 10.9747, Discriminator Loss = 0.6832
# Epoch 191: Generator Loss = 12.2647, Discriminator Loss = 0.6748
#
# Starting epoch 192/5000
# Batch 0: Generator Loss = 12.2732, Discriminator Loss = 0.6715
# Batch 10: Generator Loss = 11.1537, Discriminator Loss = 0.6764
# Epoch 192: Generator Loss = 12.0008, Discriminator Loss = 0.6751
#
# Starting epoch 193/5000
# Batch 0: Generator Loss = 13.5536, Discriminator Loss = 0.6609
# Batch 10: Generator Loss = 10.8944, Discriminator Loss = 0.6800
# Epoch 193: Generator Loss = 11.8908, Discriminator Loss = 0.6748
#
# Starting epoch 194/5000
# Batch 0: Generator Loss = 11.6819, Discriminator Loss = 0.6776
# Batch 10: Generator Loss = 10.0261, Discriminator Loss = 0.6865
# Epoch 194: Generator Loss = 12.2009, Discriminator Loss = 0.6745
#
# Starting epoch 195/5000
# Batch 0: Generator Loss = 11.3233, Discriminator Loss = 0.6756
# Batch 10: Generator Loss = 12.7959, Discriminator Loss = 0.6680
# Epoch 195: Generator Loss = 11.9370, Discriminator Loss = 0.6747
#
# Starting epoch 196/5000
# Batch 0: Generator Loss = 9.7810, Discriminator Loss = 0.6824
# Batch 10: Generator Loss = 12.4095, Discriminator Loss = 0.6719
# Epoch 196: Generator Loss = 11.8355, Discriminator Loss = 0.6749
#
# Starting epoch 197/5000
# Batch 0: Generator Loss = 11.1679, Discriminator Loss = 0.6746
# Batch 10: Generator Loss = 10.1452, Discriminator Loss = 0.6862
# Epoch 197: Generator Loss = 12.0197, Discriminator Loss = 0.6744
#
# Starting epoch 198/5000
# Batch 0: Generator Loss = 14.8501, Discriminator Loss = 0.6619
# Batch 10: Generator Loss = 15.8340, Discriminator Loss = 0.6664
# Epoch 198: Generator Loss = 12.3325, Discriminator Loss = 0.6747
#
# Starting epoch 199/5000
# Batch 0: Generator Loss = 10.8220, Discriminator Loss = 0.6808
# Batch 10: Generator Loss = 10.6839, Discriminator Loss = 0.6783
# Epoch 199: Generator Loss = 12.1011, Discriminator Loss = 0.6742
#
# Starting epoch 200/5000
# Batch 0: Generator Loss = 13.3032, Discriminator Loss = 0.6734
# Batch 10: Generator Loss = 11.6152, Discriminator Loss = 0.6762
# Epoch 200: Generator Loss = 11.6544, Discriminator Loss = 0.6741
#
# Starting epoch 201/5000
# Batch 0: Generator Loss = 11.7295, Discriminator Loss = 0.6865
# Batch 10: Generator Loss = 12.1786, Discriminator Loss = 0.6781
# Epoch 201: Generator Loss = 11.5691, Discriminator Loss = 0.6742
#
# Starting epoch 202/5000
# Batch 0: Generator Loss = 10.2588, Discriminator Loss = 0.6857
# Batch 10: Generator Loss = 12.7189, Discriminator Loss = 0.6725
# Epoch 202: Generator Loss = 11.6683, Discriminator Loss = 0.6747
#
# Starting epoch 203/5000
# Batch 0: Generator Loss = 13.4198, Discriminator Loss = 0.6654
# Batch 10: Generator Loss = 11.4387, Discriminator Loss = 0.6734
# Epoch 203: Generator Loss = 11.5490, Discriminator Loss = 0.6732
#
# Starting epoch 204/5000
# Batch 0: Generator Loss = 10.9424, Discriminator Loss = 0.6856
# Batch 10: Generator Loss = 10.8642, Discriminator Loss = 0.6798
# Epoch 204: Generator Loss = 11.7099, Discriminator Loss = 0.6746
#
# Starting epoch 205/5000
# Batch 0: Generator Loss = 14.4529, Discriminator Loss = 0.6583
# Batch 10: Generator Loss = 12.2567, Discriminator Loss = 0.6707
# Epoch 205: Generator Loss = 11.9233, Discriminator Loss = 0.6741
#
# Starting epoch 206/5000
# Batch 0: Generator Loss = 10.6230, Discriminator Loss = 0.6867
# Batch 10: Generator Loss = 13.5349, Discriminator Loss = 0.6637
# Epoch 206: Generator Loss = 11.7365, Discriminator Loss = 0.6747
#
# Starting epoch 207/5000
# Batch 0: Generator Loss = 11.5605, Discriminator Loss = 0.6711
# Batch 10: Generator Loss = 12.2544, Discriminator Loss = 0.6649
# Epoch 207: Generator Loss = 11.5967, Discriminator Loss = 0.6734
#
# Starting epoch 208/5000
# Batch 0: Generator Loss = 11.5375, Discriminator Loss = 0.6791
# Batch 10: Generator Loss = 11.1347, Discriminator Loss = 0.6738
# Epoch 208: Generator Loss = 11.7046, Discriminator Loss = 0.6742
#
# Starting epoch 209/5000
# Batch 0: Generator Loss = 11.4384, Discriminator Loss = 0.6721
# Batch 10: Generator Loss = 10.4028, Discriminator Loss = 0.6855
# Epoch 209: Generator Loss = 11.6297, Discriminator Loss = 0.6741
#
# Starting epoch 210/5000
# Batch 0: Generator Loss = 14.0574, Discriminator Loss = 0.6796
# Batch 10: Generator Loss = 11.7341, Discriminator Loss = 0.6677
# Epoch 210: Generator Loss = 11.6518, Discriminator Loss = 0.6735
#
# Starting epoch 211/5000
# Batch 0: Generator Loss = 12.0458, Discriminator Loss = 0.6714
# Batch 10: Generator Loss = 13.6785, Discriminator Loss = 0.6603
# Epoch 211: Generator Loss = 11.8714, Discriminator Loss = 0.6749
#
# Starting epoch 212/5000
# Batch 0: Generator Loss = 12.8846, Discriminator Loss = 0.6819
# Batch 10: Generator Loss = 12.0516, Discriminator Loss = 0.6676
# Epoch 212: Generator Loss = 11.6185, Discriminator Loss = 0.6738
#
# Starting epoch 213/5000
# Batch 0: Generator Loss = 12.2906, Discriminator Loss = 0.6664
# Batch 10: Generator Loss = 11.4698, Discriminator Loss = 0.6638
# Epoch 213: Generator Loss = 11.3347, Discriminator Loss = 0.6734
#
# Starting epoch 214/5000
# Batch 0: Generator Loss = 12.0749, Discriminator Loss = 0.6694
# Batch 10: Generator Loss = 11.8725, Discriminator Loss = 0.6742
# Epoch 214: Generator Loss = 11.8653, Discriminator Loss = 0.6745
#
# Starting epoch 215/5000
# Batch 0: Generator Loss = 10.4052, Discriminator Loss = 0.6810
# Batch 10: Generator Loss = 11.8548, Discriminator Loss = 0.6742
# Epoch 215: Generator Loss = 11.8741, Discriminator Loss = 0.6727
#
# Starting epoch 216/5000
# Batch 0: Generator Loss = 13.0649, Discriminator Loss = 0.6668
# Batch 10: Generator Loss = 11.2121, Discriminator Loss = 0.6733
# Epoch 216: Generator Loss = 11.4827, Discriminator Loss = 0.6741
#
# Starting epoch 217/5000
# Batch 0: Generator Loss = 12.2707, Discriminator Loss = 0.6743
# Batch 10: Generator Loss = 11.0638, Discriminator Loss = 0.6760
# Epoch 217: Generator Loss = 11.3828, Discriminator Loss = 0.6727
#
# Starting epoch 218/5000
# Batch 0: Generator Loss = 10.5832, Discriminator Loss = 0.6738
# Batch 10: Generator Loss = 10.7070, Discriminator Loss = 0.6847
# Epoch 218: Generator Loss = 11.3959, Discriminator Loss = 0.6739
#
# Starting epoch 219/5000
# Batch 0: Generator Loss = 11.6059, Discriminator Loss = 0.6769
# Batch 10: Generator Loss = 10.0785, Discriminator Loss = 0.6831
# Epoch 219: Generator Loss = 11.3602, Discriminator Loss = 0.6738
#
# Starting epoch 220/5000
# Batch 0: Generator Loss = 10.5622, Discriminator Loss = 0.6743
# Batch 10: Generator Loss = 11.0362, Discriminator Loss = 0.6733
# Epoch 220: Generator Loss = 11.4127, Discriminator Loss = 0.6725
#
# Starting epoch 221/5000
# Batch 0: Generator Loss = 11.6259, Discriminator Loss = 0.6782
# Batch 10: Generator Loss = 11.2107, Discriminator Loss = 0.6727
# Epoch 221: Generator Loss = 11.3795, Discriminator Loss = 0.6739
#
# Starting epoch 222/5000
# Batch 0: Generator Loss = 10.9808, Discriminator Loss = 0.6734
# Batch 10: Generator Loss = 12.0817, Discriminator Loss = 0.6735
# Epoch 222: Generator Loss = 11.4117, Discriminator Loss = 0.6731
#
# Starting epoch 223/5000
# ...
# Batch 0: Generator Loss = 2.3999, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.1322, Discriminator Loss = 0.6937
# Epoch 4927: Generator Loss = 2.4387, Discriminator Loss = 0.6933
#
# Starting epoch 4928/5000
# Batch 0: Generator Loss = 2.5204, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.1352, Discriminator Loss = 0.6936
# Epoch 4928: Generator Loss = 2.3822, Discriminator Loss = 0.6933
#
# Starting epoch 4929/5000
# Batch 0: Generator Loss = 2.2590, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.4126, Discriminator Loss = 0.6931
# Epoch 4929: Generator Loss = 2.3935, Discriminator Loss = 0.6934
#
# Starting epoch 4930/5000
# Batch 0: Generator Loss = 2.4613, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.2757, Discriminator Loss = 0.6932
# Epoch 4930: Generator Loss = 2.4483, Discriminator Loss = 0.6933
#
# Starting epoch 4931/5000
# Batch 0: Generator Loss = 2.4461, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.5000, Discriminator Loss = 0.6931
# Epoch 4931: Generator Loss = 2.5460, Discriminator Loss = 0.6934
#
# Starting epoch 4932/5000
# Batch 0: Generator Loss = 2.5778, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.4886, Discriminator Loss = 0.6934
# Epoch 4932: Generator Loss = 2.4851, Discriminator Loss = 0.6933
#
# Starting epoch 4933/5000
# Batch 0: Generator Loss = 2.3601, Discriminator Loss = 0.6940
# Batch 10: Generator Loss = 2.1577, Discriminator Loss = 0.6936
# Epoch 4933: Generator Loss = 2.4698, Discriminator Loss = 0.6933
#
# Starting epoch 4934/5000
# Batch 0: Generator Loss = 2.8078, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.4171, Discriminator Loss = 0.6932
# Epoch 4934: Generator Loss = 2.4308, Discriminator Loss = 0.6934
#
# Starting epoch 4935/5000
# Batch 0: Generator Loss = 2.4066, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.3171, Discriminator Loss = 0.6934
# Epoch 4935: Generator Loss = 2.4647, Discriminator Loss = 0.6933
#
# Starting epoch 4936/5000
# Batch 0: Generator Loss = 2.4921, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.8011, Discriminator Loss = 0.6924
# Epoch 4936: Generator Loss = 2.4821, Discriminator Loss = 0.6933
#
# Starting epoch 4937/5000
# Batch 0: Generator Loss = 2.6678, Discriminator Loss = 0.6927
# Batch 10: Generator Loss = 2.3720, Discriminator Loss = 0.6932
# Epoch 4937: Generator Loss = 2.4906, Discriminator Loss = 0.6933
#
# Starting epoch 4938/5000
# Batch 0: Generator Loss = 2.3303, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.4283, Discriminator Loss = 0.6934
# Epoch 4938: Generator Loss = 2.4583, Discriminator Loss = 0.6933
#
# Starting epoch 4939/5000
# Batch 0: Generator Loss = 2.4838, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.3199, Discriminator Loss = 0.6933
# Epoch 4939: Generator Loss = 2.4902, Discriminator Loss = 0.6933
#
# Starting epoch 4940/5000
# Batch 0: Generator Loss = 2.2308, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.2762, Discriminator Loss = 0.6933
# Epoch 4940: Generator Loss = 2.4142, Discriminator Loss = 0.6934
#
# Starting epoch 4941/5000
# Batch 0: Generator Loss = 2.7923, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.4099, Discriminator Loss = 0.6933
# Epoch 4941: Generator Loss = 2.4152, Discriminator Loss = 0.6933
#
# Starting epoch 4942/5000
# Batch 0: Generator Loss = 2.5434, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.6691, Discriminator Loss = 0.6928
# Epoch 4942: Generator Loss = 2.3922, Discriminator Loss = 0.6933
#
# Starting epoch 4943/5000
# Batch 0: Generator Loss = 2.5008, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.2677, Discriminator Loss = 0.6935
# Epoch 4943: Generator Loss = 2.4008, Discriminator Loss = 0.6934
#
# Starting epoch 4944/5000
# Batch 0: Generator Loss = 2.7384, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.1713, Discriminator Loss = 0.6935
# Epoch 4944: Generator Loss = 2.4543, Discriminator Loss = 0.6933
#
# Starting epoch 4945/5000
# Batch 0: Generator Loss = 2.4636, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.3894, Discriminator Loss = 0.6936
# Epoch 4945: Generator Loss = 2.4181, Discriminator Loss = 0.6934
#
# Starting epoch 4946/5000
# Batch 0: Generator Loss = 2.6323, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.1880, Discriminator Loss = 0.6935
# Epoch 4946: Generator Loss = 2.3589, Discriminator Loss = 0.6933
#
# Starting epoch 4947/5000
# Batch 0: Generator Loss = 2.5794, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.8478, Discriminator Loss = 0.6933
# Epoch 4947: Generator Loss = 2.4358, Discriminator Loss = 0.6934
#
# Starting epoch 4948/5000
# Batch 0: Generator Loss = 2.4050, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.2961, Discriminator Loss = 0.6936
# Epoch 4948: Generator Loss = 2.4331, Discriminator Loss = 0.6934
#
# Starting epoch 4949/5000
# Batch 0: Generator Loss = 2.5771, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.4632, Discriminator Loss = 0.6932
# Epoch 4949: Generator Loss = 2.4260, Discriminator Loss = 0.6934
#
# Starting epoch 4950/5000
# Batch 0: Generator Loss = 2.4660, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.4838, Discriminator Loss = 0.6930
# Epoch 4950: Generator Loss = 2.4209, Discriminator Loss = 0.6933
#
# Starting epoch 4951/5000
# Batch 0: Generator Loss = 2.4168, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.3570, Discriminator Loss = 0.6932
# Epoch 4951: Generator Loss = 2.3528, Discriminator Loss = 0.6933
#
# Starting epoch 4952/5000
# Batch 0: Generator Loss = 2.4469, Discriminator Loss = 0.6939
# Batch 10: Generator Loss = 2.3281, Discriminator Loss = 0.6936
# Epoch 4952: Generator Loss = 2.3701, Discriminator Loss = 0.6934
#
# Starting epoch 4953/5000
# Batch 0: Generator Loss = 2.3438, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.1311, Discriminator Loss = 0.6935
# Epoch 4953: Generator Loss = 2.4430, Discriminator Loss = 0.6933
#
# Starting epoch 4954/5000
# Batch 0: Generator Loss = 2.6958, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.5606, Discriminator Loss = 0.6935
# Epoch 4954: Generator Loss = 2.5090, Discriminator Loss = 0.6933
#
# Starting epoch 4955/5000
# Batch 0: Generator Loss = 2.5601, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.2739, Discriminator Loss = 0.6932
# Epoch 4955: Generator Loss = 2.4380, Discriminator Loss = 0.6934
#
# Starting epoch 4956/5000
# Batch 0: Generator Loss = 2.4424, Discriminator Loss = 0.6928
# Batch 10: Generator Loss = 2.5122, Discriminator Loss = 0.6936
# Epoch 4956: Generator Loss = 2.5181, Discriminator Loss = 0.6933
#
# Starting epoch 4957/5000
# Batch 0: Generator Loss = 2.4060, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.3714, Discriminator Loss = 0.6930
# Epoch 4957: Generator Loss = 2.4421, Discriminator Loss = 0.6934
#
# Starting epoch 4958/5000
# Batch 0: Generator Loss = 2.7530, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.6737, Discriminator Loss = 0.6937
# Epoch 4958: Generator Loss = 2.4542, Discriminator Loss = 0.6934
#
# Starting epoch 4959/5000
# Batch 0: Generator Loss = 2.3732, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.2405, Discriminator Loss = 0.6933
# Epoch 4959: Generator Loss = 2.4882, Discriminator Loss = 0.6933
#
# Starting epoch 4960/5000
# Batch 0: Generator Loss = 2.4436, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.3347, Discriminator Loss = 0.6931
# Epoch 4960: Generator Loss = 2.4863, Discriminator Loss = 0.6933
#
# Starting epoch 4961/5000
# Batch 0: Generator Loss = 2.3964, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.3395, Discriminator Loss = 0.6936
# Epoch 4961: Generator Loss = 2.3414, Discriminator Loss = 0.6934
#
# Starting epoch 4962/5000
# Batch 0: Generator Loss = 2.3012, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.3996, Discriminator Loss = 0.6934
# Epoch 4962: Generator Loss = 2.3816, Discriminator Loss = 0.6933
#
# Starting epoch 4963/5000
# Batch 0: Generator Loss = 2.6091, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.2674, Discriminator Loss = 0.6930
# Epoch 4963: Generator Loss = 2.3980, Discriminator Loss = 0.6934
#
# Starting epoch 4964/5000
# Batch 0: Generator Loss = 2.5404, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.7495, Discriminator Loss = 0.6933
# Epoch 4964: Generator Loss = 2.3873, Discriminator Loss = 0.6934
#
# Starting epoch 4965/5000
# Batch 0: Generator Loss = 2.4247, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.5894, Discriminator Loss = 0.6936
# Epoch 4965: Generator Loss = 2.4360, Discriminator Loss = 0.6933
#
# Starting epoch 4966/5000
# Batch 0: Generator Loss = 2.4312, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.3542, Discriminator Loss = 0.6933
# Epoch 4966: Generator Loss = 2.4289, Discriminator Loss = 0.6933
#
# Starting epoch 4967/5000
# Batch 0: Generator Loss = 2.4543, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.1004, Discriminator Loss = 0.6936
# Epoch 4967: Generator Loss = 2.3975, Discriminator Loss = 0.6934
#
# Starting epoch 4968/5000
# Batch 0: Generator Loss = 2.8362, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.2076, Discriminator Loss = 0.6931
# Epoch 4968: Generator Loss = 2.3560, Discriminator Loss = 0.6934
#
# Starting epoch 4969/5000
# Batch 0: Generator Loss = 2.5103, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.4238, Discriminator Loss = 0.6936
# Epoch 4969: Generator Loss = 2.4180, Discriminator Loss = 0.6934
#
# Starting epoch 4970/5000
# Batch 0: Generator Loss = 2.5924, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.3941, Discriminator Loss = 0.6934
# Epoch 4970: Generator Loss = 2.3911, Discriminator Loss = 0.6933
#
# Starting epoch 4971/5000
# Batch 0: Generator Loss = 2.1814, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.1326, Discriminator Loss = 0.6934
# Epoch 4971: Generator Loss = 2.3844, Discriminator Loss = 0.6934
#
# Starting epoch 4972/5000
# Batch 0: Generator Loss = 2.4903, Discriminator Loss = 0.6939
# Batch 10: Generator Loss = 2.3737, Discriminator Loss = 0.6933
# Epoch 4972: Generator Loss = 2.3915, Discriminator Loss = 0.6934
#
# Starting epoch 4973/5000
# Batch 0: Generator Loss = 2.6232, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.3174, Discriminator Loss = 0.6934
# Epoch 4973: Generator Loss = 2.4012, Discriminator Loss = 0.6934
#
# Starting epoch 4974/5000
# Batch 0: Generator Loss = 2.5579, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.3262, Discriminator Loss = 0.6933
# Epoch 4974: Generator Loss = 2.4354, Discriminator Loss = 0.6933
#
# Starting epoch 4975/5000
# Batch 0: Generator Loss = 2.4946, Discriminator Loss = 0.6929
# Batch 10: Generator Loss = 2.4243, Discriminator Loss = 0.6935
# Epoch 4975: Generator Loss = 2.3993, Discriminator Loss = 0.6934
#
# Starting epoch 4976/5000
# Batch 0: Generator Loss = 2.4060, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.2215, Discriminator Loss = 0.6938
# Epoch 4976: Generator Loss = 2.4245, Discriminator Loss = 0.6934
#
# Starting epoch 4977/5000
# Batch 0: Generator Loss = 2.5794, Discriminator Loss = 0.6935
# Batch 10: Generator Loss = 2.4173, Discriminator Loss = 0.6933
# Epoch 4977: Generator Loss = 2.4658, Discriminator Loss = 0.6934
#
# Starting epoch 4978/5000
# Batch 0: Generator Loss = 2.2671, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.2179, Discriminator Loss = 0.6932
# Epoch 4978: Generator Loss = 2.3905, Discriminator Loss = 0.6933
#
# Starting epoch 4979/5000
# Batch 0: Generator Loss = 2.5079, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.5830, Discriminator Loss = 0.6932
# Epoch 4979: Generator Loss = 2.4034, Discriminator Loss = 0.6933
#
# Starting epoch 4980/5000
# Batch 0: Generator Loss = 2.2564, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.4423, Discriminator Loss = 0.6935
# Epoch 4980: Generator Loss = 2.3419, Discriminator Loss = 0.6933
#
# Starting epoch 4981/5000
# Batch 0: Generator Loss = 2.4101, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.3932, Discriminator Loss = 0.6942
# Epoch 4981: Generator Loss = 2.4135, Discriminator Loss = 0.6933
#
# Starting epoch 4982/5000
# Batch 0: Generator Loss = 2.2968, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.4600, Discriminator Loss = 0.6935
# Epoch 4982: Generator Loss = 2.4257, Discriminator Loss = 0.6934
#
# Starting epoch 4983/5000
# Batch 0: Generator Loss = 2.6267, Discriminator Loss = 0.6930
# Batch 10: Generator Loss = 2.7390, Discriminator Loss = 0.6929
# Epoch 4983: Generator Loss = 2.4384, Discriminator Loss = 0.6933
#
# Starting epoch 4984/5000
# Batch 0: Generator Loss = 2.2160, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.2973, Discriminator Loss = 0.6936
# Epoch 4984: Generator Loss = 2.4300, Discriminator Loss = 0.6934
#
# Starting epoch 4985/5000
# Batch 0: Generator Loss = 2.5824, Discriminator Loss = 0.6927
# Batch 10: Generator Loss = 2.2102, Discriminator Loss = 0.6934
# Epoch 4985: Generator Loss = 2.5367, Discriminator Loss = 0.6933
#
# Starting epoch 4986/5000
# Batch 0: Generator Loss = 2.8036, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.5369, Discriminator Loss = 0.6930
# Epoch 4986: Generator Loss = 2.5110, Discriminator Loss = 0.6933
#
# Starting epoch 4987/5000
# Batch 0: Generator Loss = 2.3854, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.3510, Discriminator Loss = 0.6936
# Epoch 4987: Generator Loss = 2.4066, Discriminator Loss = 0.6933
#
# Starting epoch 4988/5000
# Batch 0: Generator Loss = 2.4534, Discriminator Loss = 0.6938
# Batch 10: Generator Loss = 2.1380, Discriminator Loss = 0.6934
# Epoch 4988: Generator Loss = 2.3937, Discriminator Loss = 0.6934
#
# Starting epoch 4989/5000
# Batch 0: Generator Loss = 2.4489, Discriminator Loss = 0.6937
# Batch 10: Generator Loss = 2.3150, Discriminator Loss = 0.6937
# Epoch 4989: Generator Loss = 2.3894, Discriminator Loss = 0.6933
#
# Starting epoch 4990/5000
# Batch 0: Generator Loss = 2.4636, Discriminator Loss = 0.6936
# Batch 10: Generator Loss = 2.2934, Discriminator Loss = 0.6933
# Epoch 4990: Generator Loss = 2.4697, Discriminator Loss = 0.6933
#
# Starting epoch 4991/5000
# Batch 0: Generator Loss = 2.3141, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.1491, Discriminator Loss = 0.6935
# Epoch 4991: Generator Loss = 2.4209, Discriminator Loss = 0.6933
#
# Starting epoch 4992/5000
# Batch 0: Generator Loss = 2.6097, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.3340, Discriminator Loss = 0.6931
# Epoch 4992: Generator Loss = 2.4335, Discriminator Loss = 0.6934
#
# Starting epoch 4993/5000
# Batch 0: Generator Loss = 2.4507, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.4850, Discriminator Loss = 0.6928
# Epoch 4993: Generator Loss = 2.4484, Discriminator Loss = 0.6933
#
# Starting epoch 4994/5000
# Batch 0: Generator Loss = 2.5259, Discriminator Loss = 0.6929
# Batch 10: Generator Loss = 2.2391, Discriminator Loss = 0.6935
# Epoch 4994: Generator Loss = 2.4588, Discriminator Loss = 0.6934
#
# Starting epoch 4995/5000
# Batch 0: Generator Loss = 2.3596, Discriminator Loss = 0.6931
# Batch 10: Generator Loss = 2.2587, Discriminator Loss = 0.6938
# Epoch 4995: Generator Loss = 2.5088, Discriminator Loss = 0.6933
#
# Starting epoch 4996/5000
# Batch 0: Generator Loss = 2.3237, Discriminator Loss = 0.6934
# Batch 10: Generator Loss = 2.1934, Discriminator Loss = 0.6934
# Epoch 4996: Generator Loss = 2.4111, Discriminator Loss = 0.6934
#
# Starting epoch 4997/5000
# Batch 0: Generator Loss = 2.6350, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.3086, Discriminator Loss = 0.6930
# Epoch 4997: Generator Loss = 2.4276, Discriminator Loss = 0.6933
#
# Starting epoch 4998/5000
# Batch 0: Generator Loss = 2.4759, Discriminator Loss = 0.6932
# Batch 10: Generator Loss = 2.2846, Discriminator Loss = 0.6936
# Epoch 4998: Generator Loss = 2.4092, Discriminator Loss = 0.6934
#
# Starting epoch 4999/5000
# Batch 0: Generator Loss = 2.5355, Discriminator Loss = 0.6933
# Batch 10: Generator Loss = 2.2612, Discriminator Loss = 0.6934
# Epoch 4999: Generator Loss = 2.3690, Discriminator Loss = 0.6933
#
# Starting epoch 5000/5000
# Batch 0: Generator Loss = 2.4648, Discriminator Loss = 0.6940
# Batch 10: Generator Loss = 2.2247, Discriminator Loss = 0.6935
# Epoch 5000: Generator Loss = 2.4556, Discriminator Loss = 0.6934
#
# Training completed in 543.27 minutes

# %%
import shutil

folder_path = '/kaggle/working/'
zip_file_path = '/kaggle/working/sample_images.zip'

# Create a zip file
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', folder_path)

# Output the path of the zip file for download
print(f"Zip file created at: {zip_file_path}")
# Out:
# Zip file created at: /kaggle/working/sample_images.zip

# %%
from tensorflow.keras.models import save_model

def save_generator_model(checkpoint_dir, save_path):
    """Load the latest checkpoint and save the generator model."""
    # Initialize a DehazeGAN model (with the same configuration as during training)
    model = DehazeGAN(image_size=(256, 256))

    # Load the latest checkpoint
    checkpoint = tf.train.Checkpoint(
        generator=model.generator,
        discriminator=model.discriminator,
        generator_optimizer=model.generator_optimizer,
        discriminator_optimizer=model.discriminator_optimizer
    )
    checkpoint_manager = tf.train.CheckpointManager(checkpoint, checkpoint_dir, max_to_keep=3)
    
    if checkpoint_manager.latest_checkpoint:
        checkpoint.restore(checkpoint_manager.latest_checkpoint)
        print(f"Restored from {checkpoint_manager.latest_checkpoint}")
    else:
        print("No checkpoint found. Make sure training has been completed.")

    # Save the generator model
    save_model(model.generator, save_path)
    print(f"Generator model saved at: {save_path}")

# Call the function to save the generator model
CHECKPOINT_DIR = './checkpoints'  # Same as the one used during training
SAVE_PATH = '/kaggle/working/generator_model.keras'  # Path to save the generator
save_generator_model(CHECKPOINT_DIR, SAVE_PATH)
# Out:
# Restored from ./checkpoints/ckpt-500
# Generator model saved at: /kaggle/working/generator_model.keras
